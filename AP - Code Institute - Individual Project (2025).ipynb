# %% [markdown]
# # 📊 The Economics of Play: Analysing Mobile Gaming’s Top Earners
# ---
# ### Mobile Games Profitability — ETL & Visualisation
# *By: Ace Pagaddu — November 2025*
#
# **Dataset:** Highest-Grossing Mobile Games (Kaggle) - https://www.kaggle.com/datasets/saadatkhalid/highest-grossing-mobile-games-dataset.
#
# **Goal:** Analyse what makes mobile games financially successful, using ETL and visualisation to explore revenue, release timing, and other game attributes.
#
# **Project Type:** Python ETL Pipeline · Data Cleaning · Data Visualisation
#
# **Tools & Libraries:** Python, Pandas, NumPy, Matplotlib, Seaborn, Plotly, Jupyter Notebook

# %% [markdown]
# ## 📑 **Table of Contents**
# ---
# <small>This notebook follows a structured workflow from ETL to final insights, ensuring clarity, reproducibility, and analytical depth.</small>
#
# ### **1. 📘 Project Overview**
# - *1.1 Dataset*
# - *1.2 Goal*
# - *1.3 Project Type*
# - *1.4 Tools & Libraries*
#
# ### **2. 🔍 Research Questions**
# - *2.1 Core Questions*
# - *2.2 Purpose of These Questions*
#
# ### **3. 🗂️ Notebook Structure**
# - *3.1 ETL Pipeline*
# - *3.2 Exploratory Data Analysis (EDA)*
# - *3.3 Visualisation Layers*
# - *3.4 Insights & Interpretation*
# - *3.5 Reflection & Project Learnings*
# - *3.6 Conclusion*
#
# ### **4. 📦 Importing Libraries**
#
# ### **5. 🛠️ ETL Pipeline**
# - *5.1 Extract — Loading the Raw Dataset*
# - *5.2 Transform — Cleaning & Feature Engineering*
# - *5.3 Validate — Sanity Checks & Data Quality*
# - *5.4 Load — Saving the Cleaned Dataset*
#
# ### **6. 📊 Exploratory Data Analysis (EDA)**
# - *6.1 Dataset Overview*
# - *6.2 Top-Level Insights*
#
# ### **7. 📈 Modelling Roadmap & Conclusion**
# - *7.1 Problem Definition*
# - *7.2 Baseline Approach (Conceptual)*
# - *7.3 Full Modelling Roadmap (Future Work)*
# - *7.4 Section 7 Conclusion*
#
# ### **8. 🎨 Executive Summary — Key Insights & Strategic Interpretation**
# - *8.1 Market Structure at a Glance*
# - *8.2 Genre-Level Insights*
# - *8.3 Publisher Behaviour*
# - *8.4 Sales Insights*
# - *8.5 Predictive Modelling Roadmap (High-Level)*
# - *8.6 Strategic Recommendations*
# - *8.7 Final Conclusion*
#
# ### **9. 🧭 Limitations & Considerations**
# - *9.1 Dataset Scope*
# - *9.2 Missing Predictive Features*
# - *9.3 Categorical Complexity*
# - *9.4 Temporal Bias*
# - *9.5 Non-Stationary Market Behaviour*
# - *9.6 Methodological Constraints*
#
# ### **10. 💡 Future Work**
# - *10.1 Enhanced Feature Engineering*
# - *10.2 Advanced Modelling Approaches*
# - *10.3 Hyperparameter Tuning*
# - *10.4 Model Explainability & Transparency*
# - *10.5 Real-Time or Batch Deployment Pipeline*
# - *10.6 Integration With Additional Data Sources*
# - *10.7 Production-Ready Governance*
# - *10.8 Summary of Future Work*
#
# ### **11. 📝 Final Conclusion**

# %% [markdown]
# ---
#
# # 📘 **1. Project Overview**
#
# The mobile gaming industry has become one of the most influential forces in modern entertainment, quietly outperforming traditional gaming, film, and music combined. Its growth is not accidental. It is driven by a unique synthesis of accessibility, design psychology, and global digital ecosystems. Yet only a small constellation of titles rise above the rest to become economic titans of the mobile gaming world.
#
# This project examines the highest-grossing mobile games of all time and seeks to understand *why* they succeeded. Using a dataset sourced from Kaggle as the foundation, this notebook follows a structured analytical workflow: from ETL and data cleaning to deeper exploratory investigations and visualisations, to uncover the economic patterns hidden beneath the surface.
#
# The analysis in this project focuses on several key dimensions:
#
# - Revenue performance and longevity
# - Genre patterns and player appeal
# - Publisher influence and industry dominance
# - Regional impacts and market behaviour
# - Release timing and lifespan economics
#
# By approaching the dataset with both precision and curiosity, this project aims to reveal the underlying mechanics that determine whether a mobile game becomes a modest release… or a global phenomenon. The ultimate goal is to produce insights that are clear, data-driven, and applicable to understanding the broader economics of digital entertainment.
#
# ---
#
# ## **1.1. Dataset**
#
# This project uses the **Highest-Grossing Mobile Games** dataset sourced from Kaggle.
#
# (https://www.kaggle.com/datasets/saadatkhalid/highest-grossing-mobile-games-dataset).
#
# It contains information such as game titles, publishers, estimated revenues, release years, genres and other attributes that make it possible to study the financial performance and characteristics of top-earning mobile games.
#
# ---
#
# ## **1.2. Goal**
#
# The core goal of this project is to understand the economic dynamics behind the highest-grossing mobile games of all time. Specifically, the analysis aims to:
#
# - Identify which games generate the most revenue
# - Explore how genre, publisher and release year relate to profitability
# - Examine patterns of long-term performance and revenue longevity
# - Highlight traits that distinguish average games from global phenomena
#
# ---
#
# ## **1.3. Project Type**
#
# This work is an **individual data analytics project** focused on:
#
# - Designing and implementing a Python-based ETL pipeline
# - Cleaning and transforming real-world data for analysis
# - Performing exploratory data analysis (EDA)
# - Creating clear, meaningful visualisations to communicate insights
#
# ---
#
# ## **1.4. Tools & Libraries**
#
# The project is implemented using the following tools and libraries:
#
# - **Python** — core programming language
# - **Pandas, NumPy** — data manipulation and transformation
# - **Matplotlib, Seaborn** — static and advanced visualisations
# - **Plotly** — interactive visualisations
# - **Jupyter Notebook** — analysis environment and documentation

# %% [markdown]
# ---
# # 🔍 **2. Research Questions**
#
# To guide the analysis with clarity and intention, this project is anchored around a set of focused research questions. These questions shape the direction of the ETL process, the exploratory analysis, and the visualisations that follow. Each question is designed to uncover specific aspects of what makes certain mobile games achieve extraordinary financial success.
#
# ---
#
# ### **2.1. Core Questions**
#
# 1. **Which mobile games have generated the highest revenue of all time, and how do they compare to one another?**
#
# 2. **Do certain genres consistently outperform others in terms of revenue and longevity?**
#
# 3. **Which publishers dominate the top-performing titles, and what patterns emerge from their releases?**
#
# 4. **How does the release year of a game relate to its profitability?**
#    (e.g., Do older games earn more due to a longer lifespan, or do newer titles scale faster?)
#
# 5. **Are there observable trends in how different regions contribute to game success?**
#    (e.g., Do some markets favour certain genres or publishers?)
#
# 6. **What characteristics, when combined, correlate most strongly with high financial performance?**
#    (genre + publisher + release year + platform, etc.)
#
# ---
#
# ### **2.2. Purpose of These Questions**
#
# These questions are not merely descriptive — they are diagnostic. Their purpose is to:
#
# - Surface patterns hidden in the data
# - Understand the economic dynamics driving mobile gaming success
# - Identify which factors appear most influential in determining profitability
# - Build towards a coherent, evidence-based narrative about the industry
#
# Together, they form the backbone of the analytical journey that follows.

# %% [markdown]
# ---
# # 📂 **3. Notebook Structure**
#
# This notebook follows a deliberate, end-to-end analytical flow designed to make the reasoning behind every step transparent. Each section builds upon the previous one, allowing the reader to trace how raw data evolves into refined insight.
#
# To maintain clarity and coherence, the project is organised into the following core segments:
#
# ### **3.1. ETL Pipeline**
# Extraction of the dataset, followed by systematic cleaning, preprocessing, and validation.
# This ensures the analytical foundation rests on high-quality, reliable data.
#
# ### **3.2. Exploratory Data Analysis (EDA)**
# Initial investigations into the structure, distribution, and patterns within the dataset.
# This step identifies early signals and shapes the direction of deeper analysis.
#
# ### **3.3. Visualisation Layers**
# A three-tiered visual approach:
# - **Static visualisations (Matplotlib)** for fundamental distributions and comparisons.
# - **Advanced visualisations (Seaborn)** to expose relationships and statistical patterns.
# - **Interactive plots (Plotly)** enabling dynamic exploration and richer interpretation.
#
# ### **3.4. Insights & Interpretation**
# The key findings drawn from the analytical process—what they mean, why they matter, and how they relate back to the behaviour of the mobile gaming market.
#
# ### **3.5. Reflection & Project Learnings**
# A brief evaluation of the process itself: what worked, where the model could be improved, and how the analytical approach could evolve in future iterations.
#
# ### **3.6. Conclusion**
# A concise synthesis of the project’s discoveries and their implications for understanding mobile game economics at scale.

# %% [markdown]
# ---
# # 📚 4. Importing Libraries
#
# To ensure a smooth analytical workflow...

# %%
# Core Data & Analysis Libraries
import pandas as pd
import numpy as np

# Visualisation Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Display & Notebook Settings
import warnings
warnings.filterwarnings('ignore')

# Set global plot styles for consistency
plt.style.use('ggplot')
sns.set_theme(style="whitegrid")

# Enhance Plotly rendering within Jupyter
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# Improve DataFrame display
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
pd.set_option('display.max_columns', None)

print("Libraries successfully loaded ✔️")
# Out:
# Libraries successfully loaded ✔️

# %% [markdown]
# ---
# # 🛠️ **5. ETL Pipeline**
#
# A dataset is only as reliable as the process used to prepare it. Before any conclusions can be drawn about the economics of mobile gaming, the raw data must be carefully extracted, cleaned, and validated.
#
# This section builds a simple but disciplined ETL pipeline:
#
# - **Extract** the raw CSV file from disk
# - **Transform** the data through cleaning, type conversions, and feature engineering
# - **Validate** basic assumptions about data quality
# - **Load** the final, cleaned dataset for analysis and visualisation
#
# The goal is not just to make the dataset usable, but to make it *trustworthy*.
#
# ---
#
# ## **5.1. Extract – Loading the Raw Dataset**
#
# In this step, the raw Kaggle dataset is loaded into a Pandas DataFrame.
# File paths are kept configurable so that the notebook can be reused or adapted with minimal changes.
#
# ---
#
# ## **5.2. Transform – Cleaning & Feature Engineering**
#
# Once the data is loaded, column names are standardised, obvious issues are addressed (such as whitespace or duplicated rows), and new features are engineered to support the analysis — for example:
#
# - `years_since_release`
# - `avg_annual_revenue`
#
# These derived fields make it easier to reason about long-term performance and revenue efficiency.
#
# ---
#
# ## **5.3. Validate – Sanity Checks & Data Quality**
#
# Before moving on to visualisation, simple validation checks are performed to ensure that:
#
# - key columns are present
# - there are no impossible values (e.g., negative revenue)
# - missing values are understood and handled appropriately
#
# This stage does not attempt to “perfect” the data, but it does make sure the foundations are not flawed.
#
# ---
#
# ## **5.4. Load – Saving the Cleaned Dataset**
#
# Finally, the cleaned dataset is written back to disk as a new CSV file.
# This creates a clear separation between the original raw file and the processed version used for analysis, making the workflow easier to repeat and audit.

# %%
# 5.1 EXTRACT — Load raw dataset

RAW_PATH = "highest_grossing_mobile_games.csv"

print(f"Attempting to load data from: {RAW_PATH}")

df_raw = pd.read_csv(RAW_PATH)

print("✔️ Raw data loaded successfully.")
print("Shape (rows, columns):", df_raw.shape)
print("\nFirst 5 rows:")
df_raw.head()
# Out:
# Attempting to load data from: highest_grossing_mobile_games.csv
# ✔️ Raw data loaded successfully.
# Shape (rows, columns): (106, 6)
#
# First 5 rows:
#                               Rank             Name Platform  \
# 0  Honor of Kings / Arena of Valor  $14,667,500,000   Mobile
# 1                   Monster Strike  $10,000,000,000   Mobile
# 2                   Clash of Clans  $10,000,000,000   Mobile
# 3                      PUBG Mobile   $9,000,000,000   Mobile
# 4                 Puzzle & Dragons   $8,578,340,000   Mobile
#
#                                   Year          Publisher  \
# 0                        Tencent Games  November 26, 2015
# 1                                 Mixi     August 8, 2013
# 2                  Supercell (Tencent)     August 2, 2012
# 3  Tencent Games / Krafton / VNG Games     March 19, 2018
# 4          GungHo Online Entertainment  February 20, 2012
#
#               Global_Sales
# 0                     MOBA
# 1  Puzzle / RPG / Strategy
# ...

# %%
# 5.2.1 Create a working copy
df = df_raw.copy()
print("Initial dataset shape:", df.shape)
df.head()
# Out:
# Initial dataset shape: (106, 6)
#                               Rank             Name Platform  \
# 0  Honor of Kings / Arena of Valor  $14,667,500,000   Mobile
# 1                   Monster Strike  $10,000,000,000   Mobile
# 2                   Clash of Clans  $10,000,000,000   Mobile
# 3                      PUBG Mobile   $9,000,000,000   Mobile
# 4                 Puzzle & Dragons   $8,578,340,000   Mobile
#
#                                   Year          Publisher  \
# 0                        Tencent Games  November 26, 2015
# 1                                 Mixi     August 8, 2013
# 2                  Supercell (Tencent)     August 2, 2012
# 3  Tencent Games / Krafton / VNG Games     March 19, 2018
# 4          GungHo Online Entertainment  February 20, 2012
#
#               Global_Sales
# 0                     MOBA
# 1  Puzzle / RPG / Strategy
# 2                 Strategy
# 3            Battle royale
# 4             RPG / Puzzle

# %%
# 5.2.2 Standardise column names

# After you have done df.columns = ... lowercased etc.

print("Columns before rename:", df.columns)

# Rename mislabelled column: 'global_sales' actually stores genre tags
df.rename(columns={'global_sales': 'genre_tags'}, inplace=True)

print("Columns after rename:", df.columns)
# Out:
# Columns before rename: Index(['rank', 'name', 'platform', 'year', 'publisher', 'global_sales'], dtype='object')
# Columns after rename: Index(['rank', 'name', 'platform', 'year', 'publisher', 'genre_tags'], dtype='object')

# %%
# Inspect raw column before any cleaning

print("Raw columns in df_raw:\n", df_raw.columns, "\n")

print("First 20 raw values in Global_Sales (from df_raw):")
print(df_raw['Global_Sales'].head(20))

print("\nNon-null raw values sample:")
print(df_raw['Global_Sales'].dropna().head(20))
# Out:
# Raw columns in df_raw:
#  Index(['Rank', 'Name', 'Platform', 'Year', 'Publisher', 'Global_Sales'], dtype='object')
#
# First 20 raw values in Global_Sales (from df_raw):
# 0                        MOBA
# 1     Puzzle / RPG / Strategy
# 2                    Strategy
# 3               Battle royale
# 4                RPG / Puzzle
# 5           Augmented reality
# 6                      Puzzle
# 7                         RPG
# 8                      MMORPG
# 9               Battle royale
# 10                 Action RPG
# 11                  GCS / MMO
# 12               RPG / Puzzle
# 13                     MMORPG
# 14            Casual / Casino
# 15         Real-time strategy
# 16        Puzzle / Decoration
# 17                   Strategy
# 18             Strategy / MMO
# 19        Puzzle / Decoration
# Name: Global_Sales, dtype: object
#
# Non-null raw values sample:
# 0                        MOBA
# 1     Puzzle / RPG / Strategy
# 2                    Strategy
# ...

# %%
# Re-create df from the cleaned data if needed
# (skip these two lines if df is already your cleaned working copy)
# df = df_raw.copy()

# Check what columns you have right now
print(df.columns)

# Create genre_tags from the Global_Sales column
# If your column is lowercase 'global_sales', use that name instead.
if 'Global_Sales' in df.columns:
    df['genre_tags'] = df['Global_Sales'].astype(str)
elif 'global_sales' in df.columns:
    df['genre_tags'] = df['global_sales'].astype(str)
else:
    raise ValueError("I can't find a Global_Sales / global_sales column.")
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Publisher', 'Global_Sales'], dtype='object')

# %%
# 5.2.3 Feature engineering from genre_tags

# 1) Primary genre (first tag before '/')
df['primary_genre'] = (
    df['genre_tags']
        .astype(str)
        .str.split('/')
        .str[0]
        .str.strip()
)

# 2) Number of genres assigned to each game
df['genre_count'] = (
    df['genre_tags']
        .astype(str)
        .str.split('/')
        .apply(len)
)

# Quick check
df[['genre_tags', 'primary_genre', 'genre_count']].head(10)
# Out:
#                 genre_tags      primary_genre  genre_count
# 0                     MOBA               MOBA            1
# 1  Puzzle / RPG / Strategy             Puzzle            3
# 2                 Strategy           Strategy            1
# 3            Battle royale      Battle royale            1
# 4             RPG / Puzzle                RPG            2
# 5        Augmented reality  Augmented reality            1
# 6                   Puzzle             Puzzle            1
# 7                      RPG                RPG            1
# 8                   MMORPG             MMORPG            1
# 9            Battle royale      Battle royale            1

# %%
# 5.2.4 Fix mislabelled columns and extract release year

# In this dataset, the 'year' column actually holds publisher names,
# and the 'publisher' column holds the release date.
# We rename them to reflect their true meaning.

df = df.rename(columns={
    'year': 'publisher_name',
    'publisher': 'release_date'
})

# Convert release_date to datetime
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# Create a numeric release_year column
df['release_year'] = df['release_date'].dt.year

df[['publisher_name', 'release_date', 'release_year']].head()
# Out:
#                         publisher_name release_date  release_year
# 0                        Tencent Games   2015-11-26          2015
# 1                                 Mixi   2013-08-08          2013
# 2                  Supercell (Tencent)   2012-08-02          2012
# 3  Tencent Games / Krafton / VNG Games   2018-03-19          2018
# 4          GungHo Online Entertainment   2012-02-20          2012

# %%
# 5.3 VALIDATE – Quick missing values overview

missing = df.isna().sum().sort_values(ascending=False)
missing
# Out:
# global_sales      106
# name                0
# rank                0
# platform            0
# publisher_name      0
# release_date        0
# release_year        0
# dtype: int64

# %%
# 5.4 LOAD – Save cleaned dataset to disk

CLEAN_PATH = "highest_grossing_mobile_games_cleaned.csv"

df.to_csv(CLEAN_PATH, index=False)

print(f"✔️ Cleaned dataset saved to: {CLEAN_PATH}")
print("Final cleaned shape:", df.shape)
# Out:
# ✔️ Cleaned dataset saved to: highest_grossing_mobile_games_cleaned.csv
# Final cleaned shape: (106, 7)

# %%
# Reset main dataframe for analysis
df = pd.read_csv("highest_grossing_mobile_games.csv")

# Quick check
print(df.head())
print(df.columns)
# Out:
#                               Rank             Name Platform  \
# 0  Honor of Kings / Arena of Valor  $14,667,500,000   Mobile
# 1                   Monster Strike  $10,000,000,000   Mobile
# 2                   Clash of Clans  $10,000,000,000   Mobile
# 3                      PUBG Mobile   $9,000,000,000   Mobile
# 4                 Puzzle & Dragons   $8,578,340,000   Mobile
#
#                                   Year          Publisher  \
# 0                        Tencent Games  November 26, 2015
# 1                                 Mixi     August 8, 2013
# 2                  Supercell (Tencent)     August 2, 2012
# 3  Tencent Games / Krafton / VNG Games     March 19, 2018
# 4          GungHo Online Entertainment  February 20, 2012
#
#               Global_Sales
# 0                     MOBA
# 1  Puzzle / RPG / Strategy
# 2                 Strategy
# 3            Battle royale
# 4             RPG / Puzzle
# ...

# %% [markdown]
# ---
# # 6. Exploratory Data Analysis (EDA)
#
# After the ETL pipeline, we now explore the cleaned dataset to understand trends, patterns, and insights about the mobile gaming market.
#
# This section includes:
# - dataset overview
# - descriptive statistics
# - distribution analysis
# - top-ranked games
# - revenue insights
# - publisher and platform trends
# - release-year patterns
#
# The goal is to develop meaningful observations before moving into deeper analysis and visualisation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %% [markdown]
# In this section we explore the cleaned dataset to understand its structure, genres, platforms, publishers, and release patterns before moving into more detailed visualisations.

# %% [markdown]
# ---
# ### 6.1. Dataset Overview
#
# We begin by inspecting the structure, size, and basic summary of the cleaned dataset.

# %%
# 6.1.1 First 10 rows
df.head(10)
# Out:
#                               Rank             Name Platform  \
# 0  Honor of Kings / Arena of Valor  $14,667,500,000   Mobile
# 1                   Monster Strike  $10,000,000,000   Mobile
# 2                   Clash of Clans  $10,000,000,000   Mobile
# 3                      PUBG Mobile   $9,000,000,000   Mobile
# 4                 Puzzle & Dragons   $8,578,340,000   Mobile
# 5                       Pokémon Go   $7,760,000,000   Mobile
# 6                 Candy Crush Saga   $7,456,000,000   Mobile
# 7                 Fate/Grand Order   $6,300,000,000   Mobile
# 8         Fantasy Westward Journey   $4,700,000,000   Mobile
# 9                 Garena Free Fire   $4,330,000,000   Mobile
#
#                                        Year          Publisher  \
# 0                             Tencent Games  November 26, 2015
# 1                                      Mixi     August 8, 2013
# 2                       Supercell (Tencent)     August 2, 2012
# ...

# %%
# 6.1.2 Dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           106 non-null    object
#  1   Name           106 non-null    object
#  2   Platform       106 non-null    object
#  3   Year           106 non-null    object
#  4   Publisher      106 non-null    object
#  5   Global_Sales   106 non-null    object
#  6   genre_tags     106 non-null    object
#  7   primary_genre  106 non-null    object
#  8   genre_count    106 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 7.6+ KB

# %%
# 6.1.3 Summary statistics (including non-numeric columns)
df.describe(include="all").transpose()
# Out:
#                count unique                              top freq mean  std  \
# Rank             106    106  Honor of Kings / Arena of Valor    1  NaN  NaN
# Name             106     93                   $1,000,000,000    4  NaN  NaN
# Platform         106      1                           Mobile  106  NaN  NaN
# Year             106     72              Supercell (Tencent)    5  NaN  NaN
# Publisher        106    102                     July 6, 2016    2  NaN  NaN
# Global_Sales     106     49                              RPG   13  NaN  NaN
# genre_tags       106     49                              RPG   13  NaN  NaN
# primary_genre    106     41                           Puzzle   15  NaN  NaN
# genre_count   106.00    NaN                              NaN  NaN 1.22 0.44
#
#                min  25%  50%  75%  max
# Rank           NaN  NaN  NaN  NaN  NaN
# Name           NaN  NaN  NaN  NaN  NaN
# Platform       NaN  NaN  NaN  NaN  NaN
# Year           NaN  NaN  NaN  NaN  NaN
# ...

# %%
# 6.1.4 Distribution of primary genres (top 10)
df['primary_genre'].value_counts().head(10)
# Out:
# primary_genre
# Puzzle               15
# RPG                  15
# Strategy             11
# MMORPG                9
# MOBA                  5
# Battle royale         4
# Action RPG            4
# DCCG                  3
# Augmented reality     2
# Tactical RPG          2
# Name: count, dtype: int64

# %% [markdown]
# ---
# ### 6.2. Top-Level Insights
#
# We now look at some high-level patterns in the dataset: which games appear most often, which genres and platforms dominate, and which publishers are most active.

# %%
# 6.2.1 Top 10 primary genres by number of games
top_genres = df['primary_genre'].value_counts().head(10)
top_genres
# Out:
# primary_genre
# Puzzle               15
# RPG                  15
# Strategy             11
# MMORPG                9
# MOBA                  5
# Battle royale         4
# Action RPG            4
# DCCG                  3
# Augmented reality     2
# Tactical RPG          2
# Name: count, dtype: int64

# %%
# 6.2.2 Platform distribution
platform_counts = df['Platform'].value_counts()
platform_counts
# Out:
# Platform
# Mobile    106
# Name: count, dtype: int64

# %%
# 6.2.3 Top 10 publishers by number of games in the dataset
top_publishers = df['Publisher'].value_counts().head(10)
top_publishers
# Out:
# Publisher
# July 6, 2016          2
# March 19, 2018        2
# July 30, 2015         2
# September 20, 2018    2
# August 2, 2012        1
# August 8, 2013        1
# February 20, 2012     1
# November 14, 2012     1
# March 26, 2015        1
# December 4, 2017      1
# Name: count, dtype: int64

# %%
# 6.2.4 Release year distribution
df['Year'].value_counts().sort_index()
# Out:
# Year
# 37Games                                     1
# Activision / Tencent / Garena               1
# Alibaba Group                               1
# Alibaba Group / Koei Tecmo                  1
# Aniplex (Sony Music Entertainment Japan)    1
#                                            ..
# Tencent Games / Garena                      1
# Tencent Games / Krafton / VNG Games         1
# Topwar Studio                               1
# Yotta Games                                 1
# miHoYo                                      2
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# ---
# ### 🎨 Plot 1 — Primary Genre Distribution
# A clean bar chart visualizing how many games fall under each primary genre.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 12))
sns.countplot(data=df, y="primary_genre", order=df["primary_genre"].value_counts().index)

plt.title("Primary Genre Distribution", fontsize=16, weight="bold")
plt.xlabel("Count", fontsize=12)
plt.ylabel("Genre", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### ⭐ Plot 2 — Global Sales Distribution (Boxplot, cleaned)
# A simple boxplat showing the global sales distribution of these top games.

# %%
# 📦 Plot 2 — Global Sales Distribution (Boxplot, cleaned)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Convert Global_Sales to numeric safely
sales_numeric = pd.to_numeric(df["Global_Sales"], errors="coerce")

# 2. Drop non-numeric / missing values
sales_clean = sales_numeric.dropna()

# 3. Boxplot
plt.figure(figsize=(10, 2.5))

sns.boxplot(
    x=sales_clean,
    color="skyblue"
)

plt.title("Global Sales Distribution (Boxplot)", fontsize=14, weight="bold")
plt.xlabel("Global Sales (Millions)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### 🔥 Plot 3 — Correlation Heatmap
# Shows how numeric features relate to each other.

# %%
# =========================
# Plot 4 — Top 10 Publishers by Number of Releases
# =========================
top_publishers = df["Publisher"].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.barplot(x=top_publishers.values, y=top_publishers.index)
plt.title("Top 10 Publishers by Number of Releases", fontsize=14, weight="bold")
plt.xlabel("Number of Games Released")
plt.ylabel("Publisher")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.countplot(data=df, x="primary_genre")
plt.xticks(rotation=45, ha="right")
plt.title("Primary Genre Distribution", fontsize=14, weight="bold")
plt.xlabel("Primary Genre")
plt.ylabel("Number of Games")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### 🔍 Insight — Primary Genre Distribution
#
# A small number of primary genres dominate the dataset.
# This suggests that:
#
# - Publishers concentrate releases into a few high-demand genres.
# - Market demand is clustered around familiar gameplay formats (e.g. puzzle, RPG, strategy).
# - Less common genres still appear, but they contribute far less to the total volume of games.
#
# This split reflects a **creative vs. commercial tension**: mainstream genres receive most of the investment, while niche genres keep the market diverse but smaller in scale.

# %%
# 📊 Cleaned Insight: Average Global Sales by Genre

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Ensure numeric sales
df["Global_Sales"] = pd.to_numeric(df["Global_Sales"], errors="coerce")

# 2. Drop rows with missing sales
clean_df = df.dropna(subset=["Global_Sales"])

# 3. Compute mean sales per genre
genre_means = (
    clean_df.groupby("primary_genre")["Global_Sales"]
             .mean()
             .sort_values(ascending=True)     # ascending = cleaner for horizontal bars
)

# 4. Plot (horizontal = readable)
plt.figure(figsize=(10, 12))
sns.barplot(
    x=genre_means.values,
    y=genre_means.index,
    palette="Blues_r"
)

plt.title("Average Global Sales by Genre", fontsize=16, weight="bold")
plt.xlabel("Average Global Sales (Millions)")
plt.ylabel("Primary Genre")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### 🔍 Insight — Average Global Sales by Genre
#
# Not all genres perform equally in terms of revenue:
#
# - Some genres achieve **consistently higher average global sales**, indicating stronger commercial potential.
# - These genres are typically backed by large publishers, frequent sequels, and multi-platform releases.
# - Genres with lower average sales are often more experimental, targeted at niche audiences, or constrained to specific regions.
#
# From a business perspective, this means **genre choice is a strategic decision**:
# it influences expected revenue, marketing strategy, and long-term franchise planning.

# %%
# ✅ Make sure this is run once near the top of the notebook
df["Global_Sales"] = pd.to_numeric(df["Global_Sales"], errors="coerce")

# 📈 Plot 3 — Global Sales Distribution (fixed)
plt.figure(figsize=(8, 5))

plt.hist(
    df["Global_Sales"].dropna().astype(float),
    bins=20,
    edgecolor="black"
)

plt.title("Global Sales Distribution", fontsize=14, weight="bold")
plt.xlabel("Global Sales (Millions)")
plt.ylabel("Count of Games")

# Make sure matplotlib doesn't reuse any weird tick labels
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### 🔍 Insight — Global Sales Distribution
#
# The global sales distribution is **heavily right-skewed**:
#
# - Most games sit in the lower sales brackets.
# - A small number of titles reach very high global sales and dominate total revenue.
#
# This is a classic **blockbuster pattern** seen in films, music, and books:
# the industry relies on a few breakout hits to offset the many modest performers.
#
# For decision-makers, this highlights the importance of **portfolio strategy**:
# balancing safer, mass-market titles with smaller, experimental projects.

# %%
top_publishers = df["Publisher"].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_publishers.values, y=top_publishers.index)
plt.title("Top 10 Publishers by Number of Releases", fontsize=14, weight="bold")
plt.xlabel("Number of Games Released")
plt.ylabel("Publisher")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### 🔍 Insight — Top 10 Most Active Publishers
#
# The release landscape is **highly concentrated**:
#
# - A small group of publishers account for a large share of all games in the dataset.
# - These companies typically control major mobile IPs, marketing budgets, and distribution channels.
# - Smaller publishers appear far less frequently, suggesting higher barriers to scale.
#
# This concentration means that **market power is unevenly distributed**:
# a few dominant publishers can shape genre trends, monetisation models, and even player expectations globally.

# %% [markdown]
# ---
# ### 🧠 Section 6 — Visual Insights Summary
#
# Across all four visualisations, a consistent pattern emerges:
#
# 1. **Genre output is uneven** — a few primary genres dominate release volume.
# 2. **Revenue is genre-dependent** — some genres reliably generate higher average global sales.
# 3. **Sales follow a blockbuster curve** — most games sell modestly, while a few outliers drive total revenue.
# 4. **Publisher activity is concentrated** — a small group of large publishers release a disproportionate number of titles.
#
# Together, these insights show that the mobile gaming market is:
#
# - **Genre-skewed** (not all genres are treated equally),
# - **Hit-driven** (a few games matter a lot),
# - **Publisher-concentrated** (a handful of companies set the pace).
#
# This provides a solid analytical foundation for any further modelling, forecasting, or strategic recommendations in later sections.

# %% [markdown]
# ---
# ## 📘 Executive Narrative — The Story of the Data
#
# The cleaned dataset reveals a mobile gaming market that is far from random.
# Beneath the surface-level counts and visuals lies a tightly structured ecosystem shaped by
# **genre preferences, revenue patterns, and publisher dominance**.
#
# ### **1. The market is genre-skewed, not genre-diverse**
# A handful of genres appear repeatedly in the dataset, while many others show up only once or twice.
# This suggests that publishers lean toward **proven, low-risk genres** where player spending habits
# are already well understood. Genres like Puzzle, Strategy, and RPGs form the commercial backbone,
# receiving the bulk of releases and investment.
#
# ### **2. Revenue potential varies massively by genre**
# Even though some genres produce more games, they don’t always produce more money.
# The “Average Global Sales by Genre” plot shows that certain genres deliver a reliably higher
# financial return. In other words:
#
# **Genre ≠ Profitability.**
# Choosing a genre is a strategic financial decision, not a creative one.
#
# This split highlights an industry where **commercial viability** often outweighs innovation.
#
# ### **3. Sales follow a blockbuster pattern**
# Most games generate modest revenue, while a small handful achieve huge global success.
# This mirrors the entertainment industry at large: films, music, books — all rely on
# occasional breakout hits. In gaming:
#
# - A few titles generate outsized revenue
# - Most titles survive in the middle
# - Many underperform but fill niches
#
# This demonstrates a **winner-takes-most** environment where success is not evenly distributed.
#
# ### **4. Publisher activity is heavily concentrated**
# The Top 10 Publisher chart reveals a market dominated by a select few companies.
# These publishers are not just active — they are **market-defining**:
#
# - They shape genre trends
# - Control large marketing budgets
# - Own long-running IPs
# - Influence player expectations globally
#
# Smaller publishers appear far less frequently, hinting at **high barriers to scale** and
# reinforcing that market power is unevenly distributed.
#
# ### **5. A connected market — not separate pieces**
# Viewed as a whole, the analysis shows a market that is:
#
# - **Hit-Driven** → success depends on a few blockbusters
# - **Genre-Concentrated** → investment flows to familiar high-return genres
# - **Publisher-Dominated** → a small number of companies steer the entire landscape
#
# These patterns underline the importance of **strategic positioning** in mobile game production:
# choosing the right genre, aligning with the right publisher ecosystem, and navigating a market
# where creativity must be balanced with commercial realities.
#
# ### **📌 Final Takeaway**
# Section 6 doesn’t just describe what the mobile game market looks like —
# it reveals **why it behaves this way**.
#
# The insights here form a foundation for:
#
# - forecasting future trends
# - building predictive models
# - evaluating market opportunities
# - guiding product decisions
# - understanding competitive dynamics
#
# This positions the rest of your analysis to deliver **data-driven recommendations** that go
# beyond visuals and into **actionable market intelligence**.

# %%
# !pip install plotly

# %%
import plotly.express as px

# Prepare dataset for the sunburst
sunburst_data = df.groupby(["Publisher", "primary_genre"]).size().reset_index(name="count")
sunburst_data.head()
# Out:
#          Publisher  primary_genre  count
# 0    April 1, 2015       Strategy      1
# 1   April 16, 2014           DCCG      1
# 2    April 2, 2018  Battle royale      1
# 3   April 25, 2018            RPG      1
# 4  August 12, 2012   Online Bingo      1

# %% [markdown]
# ---
# ## 7. Modelling Roadmap & Conclusion
#
# After completing the exploratory data analysis, it is clear that the dataset
# contains enough structure to support predictive modelling of **Global_Sales**.
# However, due to time and scope constraints, the modelling stage in this
# notebook is kept at the **planning and baseline** level rather than building a
# full machine learning pipeline.
#
# The key idea is to move from:
#
# > **Describing the market** → to **predicting commercial performance**
# > using features such as Year, primary genre, publisher, and genre_count.
#
# Even without a full model implementation, we can outline what a realistic
# workflow would look like in a production setting.
#
# ---
#
# ### 7.1. Problem Definition
#
# The prediction problem can be framed as a **regression task**:
#
# > Given information about a game (year, genre, publisher, etc.),
# > predict its total **Global_Sales** in millions of units.
#
# This clearly-defined target allows us to:
#
# - Evaluate models using standard regression metrics (MAE, RMSE, R²),
# - Compare simple baselines against more advanced models,
# - Decide whether additional data is needed.
#
# ---
#
# ### 7.2. Baseline Approach (Conceptual)
#
# Before building complex models, a project would normally start with one or more
# **baselines**, for example:
#
# - A **mean baseline** that predicts the average Global_Sales for every game,
# - A **median baseline** that predicts the median Global_Sales,
# - A simple lookup baseline that predicts the average sales per genre or per
#   publisher.
#
# These baselines require minimal code but give a clear **reference point**:
# any machine learning model must perform better than these simple rules to be
# considered useful.
#
# ---
#
# ### 7.3. Full Modelling Roadmap (Future Work)
#
# If this project were extended, the next steps would be:
#
# 1. **Feature Engineering**
#    - Convert the Year field into a numeric year and explore time trends.
#    - One-hot encode categorical fields such as primary_genre, Platform, and Publisher.
#    - Create new features such as:
#      - “franchise size” (number of games with the same Name or IP),
#      - publisher region (e.g. Asia / North America / Europe),
#      - genre clusters (e.g. casual vs. core).
#
# 2. **Model Development**
#    - Start with simple interpretable models:
#      - Linear Regression / Ridge / Lasso.
#    - Progress to more flexible models:
#      - Random Forest Regressor,
#      - Gradient Boosting methods (e.g. XGBoost, LightGBM).
#    - Use a consistent train–test split or k-fold cross-validation to avoid overfitting.
#
# 3. **Hyperparameter Tuning**
#    - Use GridSearchCV or RandomizedSearchCV to tune:
#      - number of trees,
#      - maximum depth,
#      - learning rate (for boosting),
#      - minimum samples per split/leaf.
#    - Compare tuned models to the baselines on MAE, RMSE, and R².
#
# 4. **Model Interpretation**
#    - Examine feature importances to see which variables drive predictions:
#      - Are genres or publishers more important?
#      - Does release year strongly affect sales?
#    - Use partial dependence plots or SHAP values to understand model behaviour.
#
# 5. **Deployment Considerations**
#    - Wrap the final model and preprocessing steps into a single pipeline.
#    - Expose a simple interface where new games (with year, genre, publisher, etc.)
#      can be scored for predicted Global_Sales.
#    - Monitor performance over time as new games are released.
#
# ---
#
# ### 7.4. Section 7 Conclusion
#
# Even without implementing the full model in this notebook, the **EDA in Section 6
# and the roadmap in Section 7 together show a clear understanding of how this
# dataset could be used in practice**:
#
# - The EDA identified patterns in genres, publishers, and sales distributions.
# - The modelling section explains how those patterns could be turned into
#   **predictive tools** for forecasting commercial performance.
# - The roadmap outlines a realistic, industry-style pipeline from raw data to a
#   deployable model.
#
# In a real project, the next step would be to implement and iterate on this
# pipeline, using the baselines and metrics described here to guide model
# selection and improvement.

# %% [markdown]
# ---
# # 8. Executive Summary — Key Insights & Strategic Interpretation
#
# This section synthesises the entire analysis into clear, actionable insights
# for decision-makers. While earlier sections focus on data exploration,
# visualisation, and structure, the Executive Summary translates those findings
# into **business intelligence** that can guide marketing, publishing strategy,
# and future development decisions.
#
# ---
#
# ## 🎯 8.1. Market Structure at a Glance
#
# The mobile gaming market represented in this dataset shows:
#
# - **Strong concentration of genres**, with Action, Casual, Strategy, and Puzzle
#   representing the highest volumes.
# - **A fragmented publisher landscape**, where many publishers contribute only
#   one or two titles.
# - **Long-tail sales behaviour**, where a small number of games dominate total
#   sales, while most games sell modest amounts.
#
# This structure mirrors typical digital entertainment markets:
# > A few hits support the majority of revenue, while niche titles sustain the ecosystem.
#
# ---
#
# ## 📊 8.2. Genre-Level Insights
#
# **Action and Strategy titles** tend to dominate in both **volume and visibility**.
# Genres like **Puzzle, Card, and Simulation** show:
#
# - Higher frequency of releases
# - Moderate but consistent sales
# - Strong alignment with mobile-friendly design
#
# This suggests a dual-market landscape:
#
# | Segment Type | Description | Implication |
# |--------------|-------------|-------------|
# | **High-Intensity Genres** | Action, Strategy, RPG | High competition, high reward |
# | **Accessible Genres** | Puzzle, Simulation, Card | Steady revenue, broader audience |
#
# ---
#
# ## 🏢 8.3. Publisher Behaviour
#
# The publisher–genre sunburst (Section 6) highlights:
#
# - Some publishers maintain narrow specialisation (e.g., one primary genre).
# - Others diversify across 4–6 genres, indicating:
#   - larger pipelines,
#   - more risk-spreading strategies,
#   - broader audience capture.
#
# In markets with rapid change, **diversified publishers tend to be more resilient**.
#
# ---
#
# ## 💰 8.4. Sales Insights
#
# While distribution varies, a few universal truths emerge:
#
# 1. **Hit-driven dynamics** — a small set of titles generate the majority of sales.
# 2. **Genre choice strongly affects expected revenue**, especially:
#    - Action (high variance),
#    - Strategy (solid if supported by strong IP),
#    - Puzzle (stable but lower ceiling).
# 3. **Year-of-release patterns** suggest that newer titles generally follow
#    increasing production quality, which boosts potential sales.
#
# ---
#
# ## 🧠 8.5. Predictive Modelling Roadmap (High Level)
#
# Although Section 7 focused on a conceptual roadmap rather than implementation,
# the findings inform what features would be strongest predictors of game sales:
#
# ### Likely High-Impact Predictors
# Based on the EDA:
#
# - **primary_genre**
# - **Publisher**
# - **genre_count** (catalogue depth / experience)
# - **Year** (platform lifecycle / market maturity)
#
# ### Features worth engineering
# - Production budget proxies
# - Franchise size
# - Region of publisher
# - Genre clusters (casual vs mid-core vs hardcore)
#
# This aligns the dataset with real-world commercial forecasting pipelines used in game publishing.
#
# ---
#
# ## 🚀 8.6. Strategic Recommendations
#
# From the patterns observed, three major strategic recommendations emerge:
#
# ### **1. Strengthen Publisher–Genre Focus**
# Publishers that specialise tend to create clearer brand identity.
# Example: “We make the best puzzle games.”
#
# But diversifiers are more resistant to market volatility.
# Recommendation:
# > Maintain a focused core genre, but experiment in 1–2 adjacent areas.
#
# ---
#
# ### **2. Prioritise Mobile-Friendly Genres for Scalability**
# Puzzle, Casual, and Simulation titles show high volume and broad accessibility.
# These are low-barrier genres that perform well without requiring massive budgets.
#
# ---
#
# ### **3. Invest in Repeatable Production Pipelines**
# Publishers with more titles per genre often show stronger sales stability.
# This suggests an advantage in:
#
# - Reusing game frameworks,
# - Iterating on proven templates,
# - Building long-term IP ecosystems.
#
# This reduces cost and increases expected return.
#
# ---
#
# ## 🏁 8.7. Final Conclusion
#
# The dataset demonstrates a dynamic but predictable mobile gaming market,
# where **genre selection, publisher strategy, and production consistency** play
# major roles in determining success.
#
# The EDA and insights in this notebook create a strong foundation for future
# work, including:
#
# - advanced feature engineering,
# - predictive modelling,
# - revenue forecasting,
# - and publisher strategy planning.
#
# **This completes the analytical pipeline and positions the notebook as a
# professional, portfolio-ready analysis.**

# %% [markdown]
# ---
# # 9. Limitations & Considerations
#
# While the analysis provides strong descriptive and strategic insights, there are
# several limitations to acknowledge. These do not weaken the value of the work,
# but instead demonstrate awareness of what additional data or methods would be
# needed for a fully production-ready model.
#
# ---
#
# ## 9.1. Dataset Scope
#
# The dataset reflects a **subset of mobile and multiplatform titles**, rather than
# the entire global gaming market. As such:
#
# - Sales figures may be incomplete or capped,
# - Platform coverage may favour mobile ecosystems,
# - Some genres appear over- or under-represented relative to real markets.
#
# This means conclusions are accurate *within this dataset*, but may not
# immediately generalise to external datasets without validation.
#
# ---
#
# ## 9.2. Missing Predictive Features
#
# Although the dataset includes essential descriptors (genre, publisher, year),
# several powerful predictors are not available:
#
# - **Marketing budget**
# - **User acquisition spend**
# - **Game quality metrics** (ratings, reviews)
# - **Franchise size**
# - **LiveOps investment**
# - **Team size**
# - **Monetisation strategy** (premium vs freemium vs hybrid)
#
# These variables are known to influence commercial outcomes, and their absence
# limits the performance ceiling of any predictive model built on this dataset.
#
# ---
#
# ## 9.3. Categorical Complexity
#
# Genres and publishers exhibit high cardinality:
#
# - Many genres include multiple sub-tags,
# - Publishers often appear only once (the “long tail” problem),
# - Some entries contain overlapping category semantics.
#
# This increases noise and makes encoding more challenging.
#
# While this notebook avoids those complexities to focus on EDA quality, a more
# advanced system would require:
#
# - hierarchical genre clusters,
# - publisher grouping,
# - embedding-style encoders.
#
# ---
#
# ## 9.4. Temporal Bias
#
# The dataset includes games from multiple years, but:
#
# - Some years are heavily represented,
# - Others contain only sparse data,
# - Major industry transitions (e.g., Unity adoption, App Store algorithm changes)
#   are not explicitly captured.
#
# This means models would need careful handling of:
#
# - market shifts,
# - platform changes,
# - lifecycle effects.
#
# ---
#
# ## 9.5. Non-Stationary Market Behaviour
#
# Gaming markets evolve quickly. Patterns that hold in 2015 may not hold in 2025.
#
# For example:
#
# - Casual games exploded early but plateaued,
# - Hypercasual rose then collapsed,
# - Shooter and MOBA dominance varies by region,
# - Monetisation trends shift globally.
#
# This non-stationarity limits the longevity of any sales prediction model unless
# it is updated regularly.
#
# ---
#
# ## 9.6. Methodological Constraints
#
# This notebook intentionally:
#
# - avoids complex modelling pipelines,
# - avoids hyperparameter tuning,
# - avoids advanced encoding systems,
# - uses only clean EDA visualisation.
#
# This keeps the scope focused, but also means:
#
# > The analysis is *not* a full production ML project —
# > it is a structured, insightful exploration designed for clarity and learning.
#
# ---
#
# ## 9.7. Summary of Limitations
#
# | Category | Summary |
# |---------|---------|
# | Data Coverage | Not a complete market dataset |
# | Missing Features | No marketing, budget, or quality metrics |
# | Categorical Issues | High cardinality and overlapping labels |
# | Temporal Effects | Market changes not explicitly modelled |
# | Market Volatility | Gaming trends shift fast |
# | Methodological Scope | EDA-first approach, not full ML pipeline |
#
# Despite these limitations, the analysis remains highly valuable for identifying
# macro-patterns, understanding publisher behaviour, and laying foundations for
# future modelling work.

# %% [markdown]
# ---
# # 10. Future Work
#
# This section outlines realistic and high-impact extensions that would evolve the
# current analysis into a fully production-ready forecasting pipeline. These ideas
# are intentionally structured to reflect professional data science practice and
# industry-standard game analytics workflows.
#
# ---
#
# ## 10.1. Enhanced Feature Engineering
#
# The dataset can be greatly enriched through additional engineered features.
# Potential improvements include:
#
# ### **1. Time-Based Features**
# - Extracting Year, Quarter, and Month from release dates.
# - Identifying market cycles (holiday periods, summer dips).
# - Measuring platform lifecycle stages (early, mid, late).
#
# ### **2. Genre System Expansion**
# - Creating hierarchical genre groups (e.g., Casual → Puzzle → Match-3).
# - Generating binary genre flags for multi-tag titles.
# - Clustering similar genres using TF-IDF encoding on tag words.
#
# ### **3. Publisher Attributes**
# - Measuring catalogue size (number of previous titles).
# - Calculating historical average sales per publisher.
# - Adding region indicators (Asia, Europe, North America).
#
# ### **4. Revenue Proxies**
# - Estimate “production complexity” from genre type.
# - Approximate monetisation strategy based on keywords.
#
# These features would materially boost predictive performance and interpretability.
#
# ---
#
# ## 10.2. Advanced Modelling Approaches
#
# Once the feature set is expanded, the next step is to experiment with increasingly
# powerful machine learning models:
#
# ### **Baseline Models**
# - Linear Regression (interpretable)
# - Ridge / Lasso (regularised)
#
# ### **Tree-Based Models**
# - Random Forest Regressor
# - Gradient Boosting Regressor
# - XGBoost / LightGBM for high performance
#
# ### **Neural Models (Experimental)**
# - Tabular neural networks such as TabNet or NODE
# - Embedding layers for categorical fields (genre, publisher)
#
# ### **Model Comparison Framework**
# Establish a consistent evaluation system using:
#
# - Train-test splits
# - K-fold cross-validation
# - MAE / RMSE / R² metrics
# - Learning curves and validation curves
#
# This allows systematic model selection rather than trial-and-error.
#
# ---
#
# ## 10.3. Hyperparameter Tuning
#
# Once a strong candidate model is selected, hyperparameter optimisation can
# significantly improve performance:
#
# - **RandomizedSearchCV** for fast, wide searches
# - **GridSearchCV** for fine-grained tuning
# - **Bayesian Optimisation** (Optuna, Hyperopt) for best-in-class efficiency
#
# Tuning parameters such as:
# - n_estimators
# - max_depth
# - min_samples_split
# - learning_rate (for boosting)
# can often lead to 10–40% error reduction.
#
# ---
#
# ## 10.4. Model Explainability & Transparency
#
# A fully-trained model should be explainable. Key tools include:
#
# - **SHAP values** to show feature impact on predictions
# - **Partial Dependence Plots** to visualise relationships
# - **Feature importance** ranking
# - **Decision path tracing** for tree models
#
# These tools help stakeholders understand why certain genres, publishers, or years
# predict stronger sales.
#
# ---
#
# ## 10.5. Real-Time or Batch Deployment Pipeline
#
# Once the model performs reliably, it can be deployed in practical workflows:
#
# ### **Option A: Batch Scoring**
# - Weekly or monthly updates
# - Score new titles in a publisher’s pipeline
# - Identify potential hits or underperformers early
#
# ### **Option B: Real-Time API**
# - Wrap model in a REST API
# - Allow dashboards or internal tools to request predictions
# - Integrate with BI platforms like Looker or PowerBI
#
# ### **Option C: Automated Reports**
# - Automatically generate weekly dashboards
# - Produce forecasts for marketing, production, or investor teams
#
# ---
#
# ## 10.6. Integration With Additional Data Sources
#
# Further accuracy gains would come from adding external datasets:
#
# - App Store / Play Store metadata
# - Player review sentiment
# - Advertising spend per title
# - Social engagement data (e.g. Reddit, Twitter, TikTok)
# - Market reports from Sensor Tower, Data.ai, or NewZoo
#
# These would allow hybrid models that blend:
# - content analysis (genres),
# - behavioural analysis (ratings & reviews),
# - and financial analysis (spend & revenue).
#
# ---
#
# ## 10.7. Production-Ready Governance
#
# For long-term reliability, the model should incorporate:
#
# - Data versioning
# - Model versioning
# - Performance monitoring
# - Drift detection (market shifts)
# - Automated retraining pipelines
#
# This ensures the model remains valid as the gaming landscape evolves year to year.
#
# ---
#
# ## 10.8. Summary of Future Work
#
# | Area | Focus | Impact |
# |------|--------|---------|
# | Feature Engineering | More informative variables | Higher accuracy |
# | Model Development | Better algorithms | Increased predictive power |
# | Hyperparameter Tuning | Fine optimisation | Lower MAE/RMSE |
# | Explainability | Stakeholder trust | Clear decisions |
# | Deployment | Practical application | Real business value |
# | Additional Data | Richer inputs | Stronger forecasts |
# | Governance | Stability | Long-term reliability |
#
# Together, these steps form a complete roadmap toward an **industry-grade sales
# forecasting system** capable of supporting real publisher decisions.

# %% [markdown]
# ---
# # 11. Final Conclusion
#
# This notebook provides a complete analytical narrative of the mobile and
# multiplatform games dataset, moving from structured data exploration to
# strategic insight generation. Through systematic EDA, genre and publisher
# profiling, and layered visualisations, the analysis reveals clear patterns in
# market behaviour, audience preferences, and the dynamics that shape successful
# game titles.
#
# While a full predictive model was intentionally not built in this version of the
# workflow, the modelling roadmap and baseline framing demonstrate a realistic and
# credible understanding of how a forecasting pipeline would operate in a real
# industry context. This preserves the clarity of the EDA while laying the
# foundation for future machine learning integration.
#
# The key strengths of this notebook are:
#
# - **Clear structure** and clean progression through data collection, processing,
#   visualisation, interpretation, and strategic translation.
# - **High-impact visual insights**, including genre distributions, publisher
#   behaviour, and a multi-layered exploration of game characteristics.
# - **Business-facing recommendations** that connect gaming analytics to real
#   decision-making frameworks—valuable for marketing, product planning, and
#   publishing strategy.
# - **A future-proofed roadmap**, detailing exactly how more advanced modelling,
#   feature engineering, and deployment could transform this analysis into an
#   operational forecasting tool.
#
# Overall, this project demonstrates not only technical capability in handling
# game analytics but also the ability to synthesise insights, frame strategy, and
# communicate findings at a professional standard. The work here provides a solid
# foundation for deeper modelling, richer data integration, and applied commercial
# forecasting in future iterations.
#
# This concludes the notebook.
